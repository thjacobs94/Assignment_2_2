# %% [markdown]
# Assignment 3: Generating Enhancements to Linear Regression Models in Jupyter Notebooks- Python

# %% [markdown]
# This notebook demonstrates a simple linear regression analysis using Python to model Salary based on Years of Experience. The first portion of the notebook documents how I worked through assignment 2. Assignment 2 work is demarcated following the "Assignment 2"

# %% [markdown]
# ***Assignment 2***

# %%
import pandas as pd

# %% [markdown]
# Imports the pandas library which is a powerful python library used when working with tabular data (like spreadsheets or CSV files).

# %%
dataset = pd.read_csv("regression_data.csv")

# %% [markdown]
# This reads the CSV file and loads the information into a dataframe which can be manipulated in python.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# This initiates Matplotlib function for plotting data points.

# %%
plt.scatter(dataset["YearsExperience"], dataset["Salary"], color="red")

# %% [markdown]
# Scatter plot with X axis being years of experience and y being salary.

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# This utilizes Sklearn's linear regression function

# %%
model = LinearRegression()

# %%
model.fit(dataset[["YearsExperience"]], dataset[["Salary"]])
# Out:
# LinearRegression()

# %% [markdown]
# Generated a linear regresssion model-- performed the coding steps one at a time.

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(dataset[["YearsExperience"]], dataset[["Salary"]])
# Out:
# LinearRegression()

# %% [markdown]
# Combined all coding steps together to develop a linear regression model.

# %%
plt.scatter(dataset["YearsExperience"], dataset["Salary"], color="red")

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(dataset[["YearsExperience"]], dataset[["Salary"]])
# Out:
# LinearRegression()

# %%
plt.plot(dataset["YearsExperience"], model.predict(dataset[["YearsExperience"]]), color="blue")
plt.title("Salary vs Experience")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# tied all steps together and then performed the overlay of the regression line.

# %%
model.score(dataset[["YearsExperience"]], dataset[["Salary"]])
# Out:
# 0.7851515863136573

# %% [markdown]
# Above-- 0.78515863 is our R-squared value for our regresssion line to evaluate our model. This consistent with our graphical representation as the plot has a positive correlation.

# %% [markdown]
# ***Assignment 3***

# %% [markdown]
# From this point forward represents my work for Assignment 3

# %% [markdown]
# To start we will generate the stats from the scipy.stats linregress program. We will identify slope, intercept, r_value, p_value, and standard error. These values will be used to enhance the graph we made above.

# %%
from scipy.stats import linregress

# %%
slope, intercept, r, p, se = linregress(dataset["YearsExperience"], dataset["Salary"])

# %%
print (f"slope={slope}")
# Out:
# slope=8285.292099903525

# %%
print (f"intercept={intercept}")
# Out:
# intercept=29203.522671240222

# %%
print (f"r={r}")
# Out:
# r=0.8860877983098836

# %%
print (f"p={p}")
# Out:
# p=0.0006406523231644838

# %%
print (f"se={se}")
# Out:
# se=1532.329456220131

# %% [markdown]
# Using the linregress function we were able to find the slope, intercept, correlation coefficient, p-value, and standard error for our linear regression line for our scatter plot.

# %% [markdown]
# Next we need to generate our y-predicted values using the slope an intercept for our linear regression line. These values will then be used to calculate our MSE (mean squared error).

# %%
y_pred = slope * dataset["YearsExperience"] + intercept

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
from sklearn.metrics import mean_squared_error

# Data
x = dataset["YearsExperience"]
y = dataset["Salary"]

# Linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)
y_pred = slope * x + intercept
mse = mean_squared_error(y, y_pred)

# Plot
plt.scatter(dataset["YearsExperience"], dataset["Salary"], color="blue")
plt.plot(x, y_pred, 'r-', label='Fitted Line')
plt.text(1.25, 55000,
         f"y = {slope:.2f}x + {intercept:.2f}\n"
         f"r = {r_value:.2f}\nMSE = {mse:.2f}",
         fontsize=12)
plt.xlabel("Years Experience")
plt.ylabel("Salary")
plt.title("Linear Regression Model of Years Experience vs Salary")
plt.legend()
plt.savefig("regression_plot_python.png")
plt.show()

# %% [markdown]
# Here we overlayed a linear regression line over the scatter plot of our data. I worked with Dr. Freitas and Omar from class to optimize the command line to generate an appropriate line and to ensure that the model information was printed in a readable manner.
